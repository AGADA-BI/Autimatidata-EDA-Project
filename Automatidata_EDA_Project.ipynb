# %%
#Import pandas library
import pandas as pd
# Load dataset into dataframe
df = pd.read_csv(r'C:\Users\Testing\Documents\projects\Automatidata project\2017_Yellow_Taxi_Trip_Data.csv')
df
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0        24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1        35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2       106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3        38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4        30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# ...           ...       ...                     ...                     ...
# 22694    14873857         2   02/24/2017 5:37:23 PM   02/24/2017 5:40:39 PM
# 22695    66632549         2   08/06/2017 4:43:59 PM   08/06/2017 5:24:47 PM
# 22696    74239933         2   09/04/2017 2:54:14 PM   09/04/2017 2:58:22 PM
# 22697    60217333         2  07/15/2017 12:56:30 PM   07/15/2017 1:08:26 PM
# 22698    17208911         1   03/02/2017 1:02:49 PM   03/02/2017 1:16:09 PM
#
# ...

# %%
# View and inspect summary information about the dataframe
df.head(10)
# Out:
#    Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0    24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1    35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2   106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3    38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4    30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 5    23345809         2   03/25/2017 8:34:11 PM   03/25/2017 8:42:11 PM
# 6    37660487         2   05/03/2017 7:04:09 PM   05/03/2017 8:03:47 PM
# 7    69059411         2   08/15/2017 5:41:06 PM   08/15/2017 6:03:05 PM
# 8     8433159         2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 9    95294817         1   11/10/2017 3:20:29 PM   11/10/2017 3:40:55 PM
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                6           3.34           1                  N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
""""
When it comes to the fare amount, it's important to take note of its distribution. 
The highest fare recorded is significantly higher at $1000 compared to the range between the 25th and 75th percentiles. 
Additionally, the presence of negative fare values raises some questions. 
As for trip distance, the majority of rides fall within the range of 1 to 3 miles, 
although there are instances where the distance exceeds 33 miles.
"""
df.describe()
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
# Sorting and interpreting the data table for two variables:trip_distance and total_amount.

df_sorted = df.sort_values(by=['trip_distance'], ascending = False)
df_sorted.head(10)
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 9280     51810714         2  06/18/2017 11:33:25 PM  06/19/2017 12:12:38 AM
# 13861    40523668         2   05/19/2017 8:20:21 AM   05/19/2017 9:20:30 AM
# 6064     49894023         2  06/13/2017 12:30:22 PM   06/13/2017 1:37:51 PM
# 10291    76319330         2  09/11/2017 11:41:04 AM  09/11/2017 12:18:58 PM
# 29       94052446         2   11/06/2017 8:30:50 PM  11/07/2017 12:00:00 AM
# 18130    90375786         1   10/26/2017 2:45:01 PM   10/26/2017 4:12:49 PM
# 5792     68023798         2   08/11/2017 2:14:01 PM   08/11/2017 3:17:31 PM
# 15350    77309977         2   09/14/2017 1:44:44 PM   09/14/2017 2:34:29 PM
# 10302    43431843         1   05/15/2017 8:11:34 AM   05/15/2017 9:03:16 AM
# 2592     51094874         2   06/16/2017 6:51:20 PM   06/16/2017 7:41:42 PM
#
#        passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %%
# Sorting the data by total amount with the top 20 values as output
sorted_total_amount = df.sort_values(by=['total_amount'], ascending=False)['total_amount']
sorted_total_amount.head(20)
# Out:
# 8476     1200.29
# 20312     450.30
# 13861     258.21
# 12511     233.74
# 15474     211.80
# 6064      179.06
# 16379     157.06
# 3582      152.30
# 11269     151.82
# 9280      150.30
# 1928      137.80
# 10291     131.80
# 6708      126.00
# 11608     123.30
# 908       121.56
# 7281      120.96
# 18130     119.31
# 13621     115.94
# 13359     111.95
# 29        111.38
# Name: total_amount, dtype: float64

# %%
# Sorting the data by total amount and printing the bottom 20 values
sorted_total_amount.tail(20)
# Out:
# 14283      0.31
# 19067      0.30
# 10506      0.00
# 5722       0.00
# 4402       0.00
# 22566      0.00
# 1646      -3.30
# 18565     -3.80
# 314       -3.80
# 5758      -3.80
# 5448      -4.30
# 4423      -4.30
# 10281     -4.30
# 8204      -4.80
# 20317     -4.80
# 11204     -5.30
# 14714     -5.30
# 17602     -5.80
# 20698     -5.80
# 12944   -120.30
# Name: total_amount, dtype: float64

# %%
# How many of each payment type are represented in the data?
"""" The output shows the frequency of different payment types in the DataFrame:

15,265 trips were paid with credit cards.
7,267 trips were paid with cash.
121 trips had no charge.
46 trips were disputed. """

df['payment_type'].value_counts()
# Out:
# 1    15265
# 2     7267
# 3      121
# 4       46
# Name: payment_type, dtype: int64

# %%
# Average tip for trips paid for with credit card.
average_cc_trip = df[df['payment_type'] == 1]['tip_amount'].mean()
print('Average credit cash trip:', average_cc_trip)

# Average tip for trips paid for with cash.
average_c_trip = df[df['payment_type']==2]['tip_amount'].mean()
print('Average cash trip:', average_c_trip)
# Out:
# Average credit cash trip: 2.7298001965279934
# Average cash trip: 0.0

# %%
# Number of times each vendor ID is represented in the data. 
vendor_id_count = df['VendorID'].value_counts()
vendor_id_count
# Out:
# 2    12626
# 1    10073
# Name: VendorID, dtype: int64

# %%
# Mean total amount for each vendor.
df.groupby(['VendorID']).mean(numeric_only=True)[['total_amount']]
# Out:
#           total_amount
# VendorID
# 1            16.298119
# 2            16.320382

# %%
# Finding payments made with only Credit cards.
credit_card_payments = df[df['payment_type'] ==1]
# Using passenger counts to get the total number of passengers that paid with credit cards. This will in turn get the number of rides paid with credit cards.
'''From the output, we can see that a total of 10,977 payments were made with credit cards.'''
credit_card_payments['passenger_count'].value_counts()
# Out:
# 1    10977
# 2     2168
# 5      775
# 3      600
# 6      451
# 4      267
# 0       27
# Name: passenger_count, dtype: int64

# %%
# Average tip amount for each passenger count (credit card payments only)
credit_card_payments.groupby(['passenger_count']).mean(numeric_only = True)[['tip_amount']]
# Out:
#                  tip_amount
# passenger_count
# 0                  2.610370
# 1                  2.714681
# 2                  2.829949
# 3                  2.726800
# 4                  2.607753
# 5                  2.762645
# 6                  2.643326
